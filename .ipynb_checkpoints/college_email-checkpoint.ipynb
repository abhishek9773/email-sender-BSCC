# %%
import pandas as pd
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
import glob
import os
from datetime import datetime

# %%
# Function to parse dates with a specific format, ignoring invalid dates
def parse_date(date_str):
    try:
        return datetime.strptime(date_str, '%Y-%m-%d')  # Adjust the format based on your actual data
    except (ValueError, TypeError):
        return pd.NaT  # Return NaT for invalid or missing dates

# %%
# Folder path to your CSV files
folder_path = 'college_data/*.csv'
files = glob.glob(folder_path)
df_list = []

# Load all CSV files
for file in files:
    try:
        df = pd.read_csv(file)
        # Convert 'Accreditation Valid Upto' to datetime, handling errors gracefully
        df['Accreditation Valid Upto'] = pd.to_datetime(df['Accreditation Valid Upto'], format='%Y-%m-%d', errors='coerce')
        df_list.append(df)
    except Exception as e:
        print(f"Error processing file {file}: {e}")
        continue  # Log the error and continue to the next file

# Concatenate all DataFrames into one
df = pd.concat(df_list, ignore_index=True)

# Filter rows where 'Accreditation Valid Upto' Year is greater than or equal to 2027
filtered_df = df[df['Accreditation Valid Upto'].dt.year >= 2027]

# Display the filtered DataFrame
filtered_df
# Out:
#                             College Code  \
# 22    16319            \t\t  View Course
# 40    16379            \t\t  View Course
# 52    16417            \t\t  View Course
# 60    16431            \t\t  View Course
# 97    16508            \t\t  View Course
# ...                                  ...
# 3040  23219            \t\t  View Course
# 3041  23220            \t\t  View Course
# 3042  23221            \t\t  View Course
# 3043  23222            \t\t  View Course
# 3058  23237            \t\t  View Course
#
#                         Name of the College/Institution  \
# 22        Gandhi Institute of Technology and Management
# 40    Dhirubhai Ambani Institute of Information and ...
# 52         Swami Vivekananda Yoga Anusandhana Samsthana
# 60      Jaypee University of Engineering and Technology
# 97    AVINASHILINGAM INSTITUTE FOR HOME SCIENCE AND ...
# ...                                                 ...
# 3040  VIVEKANANDA INSTITUTE OF PROFESSIONAL STUDIES,...
# 3041    LAKSHMI NARAIN COLLEGE OF TECHNOLOGY EXCELLENCE
# 3042                             DESH BHAGAT UNIVERSITY
# 3043   SANAKA EDUCATIONAL TRUST'S GROUP OF INSTITUTIONS
# 3058  DOLPHIN (PG) INSTITUTE OF BIOMEDICAL AND NATUR...
#
#                                              University           State  \
# 22                              Deemed to be University  Andhra Pradesh
# 40    Dhirubhai Ambani Institute of Information and ...         Gujarat
# 52                              Deemed-to-be-University       Karnataka
# 60      JAYPEE UNIVERSITY OF ENGINEERING AND TECHNOLOGY  Madhya Pradesh
# 97                                        Not Available      Tamil Nadu
# ...                                                 ...             ...
# 3040          Guru Gobind Singh Indraprastha University           Delhi
# 3041   Rajiv Gandhi Proudyogiki Vishwavidyalaya, Bhopal  Madhya Pradesh
# 3042                             Desh Bhagat University          Punjab
# 3043  Maulana Abul Kalam Azad University of Technolo...     West Bengal
# 3058         Hemwati Nandan Bahuguna Garhwal University     Uttarakhand
#
#           District Name Pincode                    Institute Email  \
# 22        Visakhapatnam  530045             registrar@gitam.edu.in
# 40          Gandhinagar  382007                  info@daiict.ac.in
# 52            Bangalore  560019              admissions@svyasa.org
# 60                 Guna  473226                 contact@juet.ac.in
# 97           Coimbatore  641043            registrar@avinuty.ac.in
# ...                 ...     ...                                ...
# 3040   North West Delhi  110034                   vipsedu@vips.edu
# 3041             Bhopal  462022          principallncte@LNCT.ac.in
# 3042    Fatehgarh Sahib  147301  registrar@deshbhagatuniversity.in
# 3043  Paschim Bardhaman  713212   sanakaeducationaltrust@gmail.com
# 3058           Dehradun  248007           mail@dolphininstitute.in
#
#          Institute Type Accreditation Type Accreditation Valid Upto  Status
# 22               Deemed           NAAC A++               2028-02-27  Active
# 40              Private            NAAC A+               2028-09-06  Active
# 52    Deemed University            NAAC A+               2028-05-18  Active
# 60              Private            NAAC A+               2028-03-20  Active
# 97              Private           NAAC A++               2027-02-21  Active
# ...                 ...                ...                      ...     ...
# 3040            Private               NAAC               2028-01-09  Active
# 3041            Private                NBA               2027-06-30  Active
# 3042            Private               NAAC               2029-05-15  Active
# 3043            Private                NBA               2027-06-30  Active
# 3058            Private               NAAC               2029-07-26  Active
#
# [187 rows x 11 columns]

# %%
# see data into different-different angle
# df.head()
# df.tail()
df['Institute Email']
df.iloc[10:50]
# Out:
#                           College Code  \
# 10   1337            \t\t  View Course
# 11   1352            \t\t  View Course
# 12  16300            \t\t  View Course
# 13  16302            \t\t  View Course
# 14  16306            \t\t  View Course
# 15  16307            \t\t  View Course
# 16  16310            \t\t  View Course
# 17  16312            \t\t  View Course
# 18  16313            \t\t  View Course
# 19  16314            \t\t  View Course
# 20  16315            \t\t  View Course
# 21  16318            \t\t  View Course
# 22  16319            \t\t  View Course
# 23  16320            \t\t  View Course
# 24  16321            \t\t  View Course
# 25  16323            \t\t  View Course
# 26  16324            \t\t  View Course
# 27  16325            \t\t  View Course
# 28  16328            \t\t  View Course
# 29  16329            \t\t  View Course
# 30  16330            \t\t  View Course
# 31  16332            \t\t  View Course
# 32  16333            \t\t  View Course
# 33  16339            \t\t  View Course
# 34  16340            \t\t  View Course
# 35  16341            \t\t  View Course
# 36  16342            \t\t  View Course
# 37  16346            \t\t  View Course
# 38  16348            \t\t  View Course
# 39  16350            \t\t  View Course
# 40  16379            \t\t  View Course
# 41  16386            \t\t  View Course
# 42  16389            \t\t  View Course
# 43  16391            \t\t  View Course
# 44  16396            \t\t  View Course
# 45  16398            \t\t  View Course
# 46  16399            \t\t  View Course
# 47  16401            \t\t  View Course
# 48  16402            \t\t  View Course
# 49  16403            \t\t  View Course
#
#                       Name of the College/Institution  \
# 10                                  MAGADH UNIVERSITY
# 11                  MAHATMA GANDHI CENTRAL UNIVERSITY
# 12                               University of Mysore
# 13                               Bangalore University
# 14                     Karnataka State Law University
# 15                                 Kuvempu University
# 16            National Law School of India University
# 17        Cochin University of Science and Technology
# 18                          Mahatma Gandhi University
# 19                              University of Calicut
# 20                                  Andhra University
# 21                       Acharya Nagarjuna University
# 22      Gandhi Institute of Technology and Management
# 23               Sri Padmavati Mahila Visvavidyalayam
# 24                        Sri Venkateswara University
# 25                                  Tezpur University
# 26                               Dibrugarh University
# 37     Government               NAAC               2021-02-18  Active
# 38     Government               NAAC               2021-02-18  Active
# 39     Government               NIRF                      NaT  Active
# 40        Private            NAAC A+               2028-09-06  Active
# 41     Government      Not Available                      NaT  Active
# 42     Government      Not Available                      NaT  Active
# 43     Government               NAAC               2022-02-21  Active
# 44     Government               NAAC               2022-03-27  Active
# 45     Government               NAAC               2022-10-29  Active
# 46     Government               NAAC               2022-02-21  Active
# 47     Government               NAAC               2024-03-27  Active
# 48     Government               NIRF                      NaT  Active
# 49     Government      Not Available                      NaT  Active

# %%
filtered_df['Institute Email']
# Out:
# 22                 registrar@gitam.edu.in
# 40                      info@daiict.ac.in
# 52                  admissions@svyasa.org
# 60                     contact@juet.ac.in
# 97                registrar@avinuty.ac.in
#                       ...
# 3040                     vipsedu@vips.edu
# 3041            principallncte@LNCT.ac.in
# 3042    registrar@deshbhagatuniversity.in
# 3043     sanakaeducationaltrust@gmail.com
# 3058             mail@dolphininstitute.in
# Name: Institute Email, Length: 187, dtype: object

# %%
# Email credentials (use your email and app password)
your_email = 'Enter_your_email'
your_password = 'Enter_your_password'  # If you have 2-factor authentication enabled, enter your app password; otherwise, enter your email password

# %%
# Paths to the files where sent emails and errors are logged
sent_log_file = 'system_log/sent_emails_log.txt'
error_log_file = 'system_log/error_log.txt'

# %%
# Create the email content
subject = "Request for Admission and Financial Assistance"
email_template = """
Dear Principal Sir/Madam,

[Introduction]
- Start with a polite greeting.
- Introduce yourself by mentioning your name and where you're from.

[Purpose of the Email]
- Explain why you're writing this email. Mention the college and program you're interested in.
- State the main reason for your email, such as requesting admission and financial assistance.

[Financial Challenges]
- Provide details about your financial situation.
- Mention any financial aid or scholarships you currently have and why they are insufficient.
- Briefly describe the financial challenges you’re facing and how they are affecting your education.

[Skills and Experience]
- Share any relevant skills or experience you've gained during your gap period or while managing financial challenges.
- Highlight how these experiences have prepared you for the program you're interested in.

[Request for Assistance]
- Clearly state your request for admission and any financial help or guidance you’re seeking.
- Express your commitment to making the most of the opportunity if given.

[Closing]
- Thank the recipient for their time and consideration.
- Mention that you’re looking forward to their response and any assistance they can provide.

[Signature]
- End the email with a polite closing.
- Include your full name.
- Optionally, add links to your LinkedIn profile and resume, as well as your contact information.
"""

# %%
# Function to send an email
def send_email(to_email, subject, body):
    try:
        msg = MIMEMultipart()
        msg['From'] = your_email
        msg['To'] = to_email
        msg['Subject'] = subject
        msg.attach(MIMEText(body, 'plain'))

        server = smtplib.SMTP('smtp.gmail.com', 587)
        server.starttls()
        server.login(your_email, your_password)
        text = msg.as_string()
        server.sendmail(your_email, to_email, text)
        server.quit()

        # Log the email as sent
        with open(sent_log_file, 'a') as log_file:
            log_file.write(f"{to_email}\n")
        print(f"Email sent to {to_email} ({college_name})")
    except Exception as e:
        # Log the error
        with open(error_log_file, 'a') as error_log:
            error_log.write(f"Failed to send email to {to_email}: {str(e)}\n")
        print(f"Failed to send email to {to_email}: {e}")

# %%
# Load the log of sent emails
if os.path.exists(sent_log_file):
    with open(sent_log_file, 'r') as log_file:
        sent_emails = set(log_file.read().splitlines())
else:
    sent_emails = set()

# Iterate through the filtered list and send personalized emails
for index, row in filtered_df.iterrows():
    to_email = row['Institute Email']

    # Skip if email was already sent
    if to_email in sent_emails:
        print(f"Skipping {to_email}, email already sent.")
        continue

    college_name = row['Name of the College/Institution']
    personalized_body = email_template.format(college_name=college_name)
    send_email(to_email, subject, personalized_body)

print("Emails sent successfully.")
# Out:
# Email sent to registrar@gitam.edu.in (Gandhi Institute of Technology and Management)
# Email sent to info@daiict.ac.in (Dhirubhai Ambani Institute of Information and Communication Technology)
# Email sent to admissions@svyasa.org (Swami Vivekananda Yoga Anusandhana Samsthana)
# Email sent to contact@juet.ac.in (Jaypee University of Engineering and Technology)
# Email sent to registrar@avinuty.ac.in (AVINASHILINGAM INSTITUTE FOR HOME SCIENCE AND HIGHER EDUCATION FOR WOMEN)
# Email sent to glauniversity@gla.ac.in (GLA University)
# Email sent to raju.sangal@jiit.ac.in (Jaypee Institute of Information Technology)
# Email sent to info@aditya.ac.in (Aditya Engineering College)
# Email sent to admissions@nrtec.in (Narasaraopeta Engineering College)
# Email sent to placements@indianacademy.edu.in (Indian Academy Degree College)
# Email sent to PRINCIPAL@GIET.AC.IN (Godavari Institute of Engineering and Technology)
# Email sent to dpvipracollege@gmail.com (D. P. Vipra College)
# Email sent to admission@acsce.edu.in (A. C. S. College of Engineering)
# Email sent to principal@dr-ait.org (Dr. Ambedkar Institute of Technology)
# Email sent to info@krupanidhi.edu.in (Krupanidhi College of Pharmacy)
# Email sent to principal@sjbit.edu.in (S. J. B. Institute of Technology)
# Email sent to tjcprincipal@tjohngroup.com (T. John College, Gottigere)
# Email sent to principal@bietdvg.edu (Bapuji Institute of Engineering and Technology)
# Email sent to kkwieer@kkwagh.edu.in (K. K. Wagh Institute of Engineering Education and Research)
# Email sent to registrar.scoe@sinhgad.edu (Sinhgad Technical Education Society's Sinhgad College of Engineering)
# Email sent to principal@ycce.edu , info@ycce.edu (Yeshwantrao Chavan College of Engineering)
# Email sent to estb.pcoemr@gmail.com (KJs Educational Institutes Trinity Academy of Engineering)
# Email sent to principal.sknsits@sinhgad.edu (SKN Sinhgad Institute of Technology and Science)
# Email sent to kcwldh@outlook.com (Khalsa College for Women)
# Email sent to nascprincipal@nehrucolleges.com (Nehru Arts and Science College)
# Email sent to principalbpharm@sanjivani.org.in (Sanjivani College of Pharmaceutical Education and Research)
# Email sent to principal@ksrce.ac.in (K. S. R. College of Engineering, Tiruchengode)
# Email sent to src.naac@gmail.com (Shri Ram College)
# Failed to send email to nan: 'float' object has no attribute 'encode'
# Email sent to admin@davpgcvns.ac.in (DAV PG College)
# Email sent to admissions.mn@its.edu.in (Institute of Technology and Science)
# Email sent to info@mahendraarts.org (Mahendra Arts & Science College)
# Email sent to admission@iul.ac.in (Integral University)
# Email sent to madhur.saxena@abes.ac.in (ABES ENGINEERING COLLEGE)
# Email sent to registrar@glbitm.org (G. L BAJAJ INSTITUTE OF TECHNOLOGY AND MANAGEMENT)
